# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
tan = pd.read_csv("training.csv")
tan.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
tan.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
tan.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %%
tan.dtypes
# Out:
# ID                               int64
# Q1                               int64
# Q2                               int64
# Q3                               int64
# Q4                               int64
# Q5                               int64
# Q6                               int64
# Q7                               int64
# Q8_1                             int64
# Q8_2                             int64
# Q8_3                             int64
# Q8_4                             int64
# Q8_5                             int64
# Q8_6                             int64
# Q8_7                             int64
# Q8_8                             int64
# Q8_9                             int64
# Q8_10                            int64
# Q8_11                            int64
# Q9                               int64
# Q10                              int64
# Q11                              int64
# Q12                              int64
# Q13                              int64
# ...

# %%
## ASSIGNING NEW VALUES AND GIVING COLOUMNS NEW NAMES
tan.rename(columns = {'Q1':'age', 'Q2':'gender', 'Q3':'marital_status', 'Q4':'highest_level_education', 'Q5':'land_ownership_status', 'Q7':'own_mobile_phone', 'Q8_1':'Salary_wages', 'Q8_2':'money_from_trading', 'Q8_3':'money_from_providing_services', 'Q8_4':'casual_labour', 'Q8_5':'rental_income', "Q8_6":"money_from_savings", "Q8_7":"pension", 'Q8_8':'government_grants', 'Q8_9':'rely_on_someone', "8_10":"no-money", 'Q8_11':'other_one', 'Q9':'salary_from_sectors', 'Q10':'money_from_selling', "Q11":"money_from_providing_services", "Q16":"m_m_usage_purchase", "Q17":"m_m-bills"}, inplace=True)

assign_gender= {1:'Male', 2:"Female"}


assign_marital_status= {1:'married', 2:'divorced', 3:'widowed', 4:'single'}

assign_mobile_money_purchase= {0:"not_applicable", 1:'never', 2:'daily', 3:'weekly', 4:'monthly', 5:'less_often_than_monthly'}
assign_mobile_money_classification= {0:'no_mm_or_other', 1:'no_mm', 2:'mm_only', 3:'mm_least_one_financial_service'}
assign_land_ownership_status= {1:'own_land_personally', 2:"joint_ownership", 3:'household_member_owner', 4:'rented_land', 5:"none", 6:"not_aware"}

# %%
tan.head()
# Out:
#      ID  age  gender  marital_status  highest_level_education  \
# 0  5086   98       2               3                        1
# 1  1258   40       1               1                        3
# 2   331   18       2               4                        6
# 3  6729   50       1               1                        3
# 4  8671   34       1               1                        1
#
#    land_ownership_status  Q6  own_mobile_phone  Salary_wages  \
# 0                      1   2                 2             0
# 1                      5   1                 1             1
# 2                      3   2                 1             0
# 3                      1   1                 1             0
# 4                      1   2                 1             0
#
#    money_from_trading  ...  m_m-bills  Q18  Q19  Latitude  Longitude  \
# 0                   0  ...         -1    4    4 -4.460442  29.811396
# 1                   0  ...          4    1    4 -6.176438  39.244871
# ...

# %%
corr = tan.corr()
corr
# Out:
#                                      ID       age    gender  marital_status  \
# ID                             1.000000  0.102517  0.006500       -0.077764
# age                            0.102517  1.000000 -0.052484       -0.161434
# gender                         0.006500 -0.052484  1.000000        0.011540
# marital_status                -0.077764 -0.161434  0.011540        1.000000
# highest_level_education       -0.153765 -0.329742 -0.117319        0.152441
# land_ownership_status         -0.149565 -0.362815  0.101568        0.175220
# Q6                             0.081115 -0.094837  0.113456        0.105623
# own_mobile_phone               0.152994  0.081805  0.184709        0.024248
# Salary_wages                  -0.111150 -0.064513 -0.084585        0.055995
# money_from_trading             0.155321  0.140593 -0.082230       -0.231267
# money_from_providing_services -0.016551 -0.045270 -0.016613       -0.001252
# ...

# %%
tan.corr()[, 'age'].sort_values().plot.bar()

# %%
cal = (100 % 100) * ('mobile_money_classification')

# %%
tan.columns
# Out:
# Index(['ID', 'age', 'gender', 'marital_status', 'highest_level_education',
#        'land_ownership_status', 'Q6', 'own_mobile_phone', 'Salary_wages',
#        'money_from_trading', 'money_from_providing_services', 'casual_labour',
#        'rental_income', 'money_from_savings', 'pension', 'government_grants',
#        'rely_on_someone', 'Q8_10', 'other_one', 'salary_from_sectors',
#        'money_from_selling', 'money_from_providing_services', 'Q12', 'Q13',
#        'Q14', 'Q15', 'm_m_usage_purchase', 'm_m-bills', 'Q18', 'Q19',
#        'Latitude', 'Longitude', 'mobile_money', 'savings', 'borrowing',
#        'insurance', 'mobile_money_classification'],
#       dtype='object')

# %%
list = ['gender']

for i in list:
    tan.groupby([i, "mobile_money_classification"]).size().unstack().plot(kind='bar', stacked=True, figsize=(15,5), )
    plt.title('{} vs mobile_money_classification'.format(i))
    plt.legend(loc='upper right')
    plt.show()

# %%
tan.head()
# Out:
#      ID  age  gender  marital_status  highest_level_education  \
# 0  5086   98       2               3                        1
# 1  1258   40       1               1                        3
# 2   331   18       2               4                        6
# 3  6729   50       1               1                        3
# 4  8671   34       1               1                        1
#
#    land_ownership_status  Q6  own_mobile_phone  Salary_wages  \
# 0                      1   2                 2             0
# 1                      5   1                 1             1
# 2                      3   2                 1             0
# 3                      1   1                 1             0
# 4                      1   2                 1             0
#
#    money_from_trading  ...  m_m-bills  Q18  Q19  Latitude  Longitude  \
# 0                   0  ...         -1    4    4 -4.460442  29.811396
# 1                   0  ...          4    1    4 -6.176438  39.244871
# ...

# %%
list = ['gender']

for i in list:
    tan.groupby([i, "land_ownership_status"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5), )
    plt.title('{} vs land_ownership_status'.format(i))
    plt.legend(loc='center')
    plt.show()

# %%
cat = {
    0 : "No_financial_services",
    1 : "Other_only",
    2 : "Mm_only",
    3 : "Mm_plus"
}
# group and get relevant data
services_marital = tan.groupby(["mobile_money_classification", "marital_status"])["ID"].count().reset_index()
font = {
    'weight' : 'normal',
    'size'   : 15
       }
# some settings to make sure client can see text.
plt.rc('font', **font)
plt.figure(figsize=(20,10))
for x in services_age["mobile_money_classification"].unique():
    plt.plot( 'marital_status', 'ID', data=services_age[services_marital.mobile_money_classification==x],
             marker='', linewidth=5, label="Label for {}".format(cat[x])
            )
plt.title("Relationship between financial services accessed (non-mobile, mobile, both) and marital_status", fontsize=20)
plt.legend()
plt.show()

# %%
# categories
cat = {
    0 : "No_financial_services",
    1 : "Other_only",
    2 : "Mm_only",
    3 : "Mm_plus"
}
# group and get relevant data
services_age = tan.groupby(["mobile_money_classification", "age"])["ID"].count().reset_index()
font = {
    'weight' : 'normal',
    'size'   : 15
       }
# some settings to make sure client can see text.
plt.rc('font', **font)
plt.figure(figsize=(20,10))
for x in services_age["mobile_money_classification"].unique():
    plt.plot( 'age', 'ID', data=services_age[services_age.mobile_money_classification==x],
             marker='', linewidth=3, label="Label for {}".format(cat[x])
            )
plt.title("Relationship between financial services accessed (non-mobile, mobile, both) and age")
plt.legend()
plt.show()

# %%
from geopy.geocoders import Nominatim
import folium
lat = -6.3728253 ; lon = 34.8924826
Country_map = folium.Map(location=[lat, lon], zoom_start=6)
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_9'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'green',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_5'):
  folium.CircleMarker(
    [lat, long],
    radius = 5,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, lng, label in zip(training[training.mobile_money == 1].Latitude,
              training[training.mobile_money == 1].Longitude,
              str(training.ID)):
  label = folium.Popup(label, parse_html=True)
  folium.CircleMarker(
    [lat, lng],
    radius=5,
    popup=label,
    color='green',
    fill=True,
    fill_color='#3186CC',
    fill_opacity=0.4,
    parse_html=False).add_to(Country_map) 
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_1'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_8'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map

# %% [markdown]
# # WE CAN CONCLUDE THAT PEOPLE WHO LIVE IN AND AROUND THE CITIES AND ARE BETWEEN THEIR 20'S AND 30'S USE MORE OF THE MOBILE MONEY SERVICES BECAUSE THEY ARE MORE EXPOSED TO THE TECNOLOGICAL ASPECT OF LIFE.THE MALES USE MORE OF THE MOBILE MONEY SERVICES THAN FEMALES BECAUSE FEMALES USE MORE OF THE OTHER FINANCIAL SERVICES THEN THE MALES
