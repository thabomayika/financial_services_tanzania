# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
tan = pd.read_csv("training.csv")
tan.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
tan.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
tan.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %%
tan.dtypes
# Out:
# ID                               int64
# Q1                               int64
# Q2                               int64
# Q3                               int64
# Q4                               int64
# Q5                               int64
# Q6                               int64
# Q7                               int64
# Q8_1                             int64
# Q8_2                             int64
# Q8_3                             int64
# Q8_4                             int64
# Q8_5                             int64
# Q8_6                             int64
# Q8_7                             int64
# Q8_8                             int64
# Q8_9                             int64
# Q8_10                            int64
# Q8_11                            int64
# Q9                               int64
# Q10                              int64
# Q11                              int64
# Q12                              int64
# Q13                              int64
# ...

# %%
## ASSIGNING NEW VALUES AND GIVING COLOUMNS NEW NAMES
tan.rename(columns = {'Q1':'age', 'Q2':'gender', 'Q3':'marital_status', 'Q4':'highest_level_education', 'Q5':'land_ownership_status', "Q6":"personal_ownership_land", 'Q7':'own_mobile_phone', 'Q8_1':'Salary_wages', 'Q8_2':'money_from_trading', 'Q8_3':'money_from_providing_services', 'Q8_4':'casual_labour', 'Q8_5':'rental_income', "Q8_6":"money_from_savings", "Q8_7":"pension", 'Q8_8':'government_grants', 'Q8_9':'rely_on_someone', "Q8_10":"no_money", 'Q8_11':'other_one', 'Q9':'salary_from_sectors', 'Q10':'money_from_selling', "Q11":"money_from_providing_services", "Q12":"sent_money_12months_ago", "Q13":"when_last_sent_money", "Q14":"received_money_12months_ago", "Q15":"when_last_received_money", "Q16":"m_m_usage_purchase", "Q17":"m_m-bills", "Q18":"kiswahahili_literate", "Q19":"english_literate"}, inplace=True)

assign_gender= {1:'Male', 2:"Female"}


assign_marital_status= {1:'Married', 2:'Divorced', 3:'Widowed', 4:'Single/never_married'}

assign_mobile_money_purchase= {0:"not_applicable", 1:'never', 2:'daily', 3:'weekly', 4:'monthly', 5:'less_often_than_monthly'}
assign_mobile_money_classification= {0:'no_mm_or_other', 1:'no_mm', 2:'mm_only', 3:'mm_least_one_financial_service'}
assign_land_ownership_status= {1:'own_land_personally', 2:"joint_ownership", 3:'household_member_owner', 4:'rented_land', 5:"none", 6:"not_aware"}

# %%
real_name = {'gender':    
{    1:'Male', 
    2:'Female'
},

'marital_status': 
{   1:'Married',
    2:'Divorced',
    3:'Widowed',
    4:'Single/never_married'
},

'highest_level_education':
{   1:'no_formal_education',
    2:'some_primary',
    3:'primary_completed',
    4:'Post_primary_technical_training',
    5:'Some_secondary',
    6:'University_or_other_higher_education',
    7:'Don’t_know'
},

'land_ownership_status':
{   1:'own_land_personally',
    2:'joint_ownership',
    3:'household_member_owner',
    4:'rented_land',
    5:'none',
    6:'not_aware'
   
},            
            
'personal_ownership_land"':
{   1:'Yes',
    2:'No'
   
},

'own_mobile_phone':
{   1:'Yes',
    2:'No'
       
},

'mobile_money_classification' :
{   0:'no_mm_or_other',
    1:'no_mm',
    2:'mm_only',
    3:'mm_least_one_financial_service'
},
            
 'mobile_money_purchase':
{   -1:'not_applicable',
    1:'never',
    2:'daily',
    3:'weekly',
    4:'monthly',
    5:'less_often_than_monthly'
},
  'kiswahahili_literate':
{   1:'Can_read_and_write',
    2:'Can_read_only',
    3:'Can_write_only',
    4:'Can_neither_read_nor_write',
    5:'Refused_to_read'
},
  'english_literate':
{   1:'Can_read_and_write',
    2:'Can_read_only',
    3:'Can_write_only',
    4:'Can_neither_read_nor_write',
    5:'Refused_to_read'
},
  'Salary_wages':
{   0:'No',
    1:'Yes'
},
  'money_from_trading':
{   0:'No',
    1:'Yes'
},             
   'money_from_providing_services':
{   0:'No',
    1:'Yes'
},                       
   'casual_labour':
{   0:'No',
    1:'Yes'
},                       
   'rental_income':
{   0:'No',
    1:'Yes'
},                        
   'money_from_savings':
{   0:'No',
    1:'Yes'
},                        
   'pension':
{   0:'No',
    1:'Yes'
},                       
   'government_grants':
{   0:'No',
    1:'Yes'   
},                       
   'rely_on_someone':
{   0:'No',
    1:'Yes'  
},
   'no_money':
{   0:'No',
    1:'Yes' 
},                       
   'other_one':
{   0:'No',
    1:'Yes' 
},                       
  
            }

tan.replace(real_name, inplace=True)

tan.head()
# Out:
#      ID  age  gender        marital_status  \
# 0  5086   98  Female               Widowed
# 1  1258   40    Male               Married
# 2   331   18  Female  Single/never_married
# 3  6729   50    Male               Married
# 4  8671   34    Male               Married
#
#                 highest_level_education   land_ownership_status  \
# 0                   no_formal_education     own_land_personally
# 1                     primary_completed                    none
# 2  University_or_other_higher_education  household_member_owner
# 3                     primary_completed     own_land_personally
# 4                   no_formal_education     own_land_personally
#
#    personal_ownership_land own_mobile_phone Salary_wages money_from_trading  \
# 0                        2               No           No                 No
# 1                        1              Yes          Yes                 No
# 2                        2              Yes           No                 No
# ...

# %%
corr = tan.corr()
corr
# Out:
#                                    ID       age  personal_ownership_land  \
# ID                           1.000000  0.102517                 0.081115
# age                          0.102517  1.000000                -0.094837
# personal_ownership_land      0.081115 -0.094837                 1.000000
# salary_from_sectors         -0.110209 -0.072472                -0.057962
# money_from_selling           0.033652  0.047705                -0.023774
# sent_money_12months_ago      0.105142  0.139266                 0.108077
# when_last_sent_money        -0.081854 -0.133105                -0.091141
# received_money_12months_ago  0.059331  0.028583                 0.046238
# when_last_received_money    -0.039055 -0.015970                -0.033287
# m_m_usage_purchase          -0.139411 -0.092381                -0.105686
# m_m-bills                   -0.139764 -0.012336                -0.117216
# Latitude                    -0.051004 -0.034037                 0.009000
# ...

# %%
tan.corr()['age'].sort_values().plot.barh(figsize=(10,10), fontsize=15)

# %%
tan.columns
# Out:
# Index(['ID', 'age', 'gender', 'marital_status', 'highest_level_education',
#        'land_ownership_status', 'personal_ownership_land', 'own_mobile_phone',
#        'Salary_wages', 'money_from_trading', 'money_from_providing_services',
#        'casual_labour', 'rental_income', 'money_from_savings', 'pension',
#        'government_grants', 'rely_on_someone', 'no_money', 'other_one',
#        'salary_from_sectors', 'money_from_selling',
#        'money_from_providing_services', 'sent_money_12months_ago',
#        'when_last_sent_money', 'received_money_12months_ago',
#        'when_last_received_money', 'm_m_usage_purchase', 'm_m-bills',
#        'kiswahahili_literate', 'english_literate', 'Latitude', 'Longitude',
#        'mobile_money', 'savings', 'borrowing', 'insurance',
#        'mobile_money_classification'],
#       dtype='object')

# %%
age = tan["age"]
gender = tan["gender"]
marital_status = tan["marital_status"]
highest_education = tan["highest_level_education"]
land_ownership = tan["land_ownership_status"]
mobile_ownership = tan["own_mobile_phone"]
financial_access = tan['mobile_money_classification']

sal = tan['Salary_wages']
trad = tan['money_from_trading']
serv = tan['money_from_providing_services']
casu = tan['casual_labour']
rent = tan['rental_income']
save = tan['money_from_savings']
pens = tan['pension']
grant = tan['government_grants']
rely = tan['rely_on_someone']
els = tan['no_money']
othr = tan['other_one']


info = {
    'Salary_wages':sal, 
    'money_from_trading':trad,
    'money_from_providing_services' :serv,
    'casual_labour' :casu,
    'rental_income' :rent,
    'money_from_savings' :save,
    'pension' :pens,
    'government_grants' :grant,
    'Rely on someone else to send money' :rely,
    'rely_on_someone' :els,
    'other_one' :othr }

income = pd.DataFrame(info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-296032ac7695> in <module>
#      33     'other_one' :othr }
#      34
# ---> 35 income = pd.DataFrame(info)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
# ...

# %%
list = ['gender']

for i in list:
    tan.groupby([i, "mobile_money_classification"]).size().unstack().plot(kind='bar', stacked=True, figsize=(15,10), fontsize=15 )
    plt.title('{} vs mobile_money_classification'.format(i), fontsize=20)
    plt.legend(loc='upper right')
    plt.show()

# %%
tan.head()
# Out:
#      ID  age  gender        marital_status  \
# 0  5086   98  Female               Widowed
# 1  1258   40    Male               Married
# 2   331   18  Female  Single/never_married
# 3  6729   50    Male               Married
# 4  8671   34    Male               Married
#
#                 highest_level_education   land_ownership_status  \
# 0                   no_formal_education     own_land_personally
# 1                     primary_completed                    none
# 2  University_or_other_higher_education  household_member_owner
# 3                     primary_completed     own_land_personally
# 4                   no_formal_education     own_land_personally
#
#    personal_ownership_land own_mobile_phone  Salary_wages  money_from_trading  \
# 0                        2               No             0                   0
# 1                        1              Yes             1                   0
# 2                        2              Yes             0                   0
# ...

# %%
list = ['gender']

for i in list:
    tan.groupby([i, "land_ownership_status"]).size().unstack().plot(kind='barh', stacked=True, figsize=(15,10), fontsize=20)
    plt.title('{} vs land_ownership_status'.format(i), fontsize=20)
    plt.legend(loc = (1.1, 0.7), fontsize=20)
    plt.show()

# %%
tan.columns
# Out:
# Index(['ID', 'age', 'gender', 'marital_status', 'highest_level_education',
#        'land_ownership_status', 'personal_ownership_land', 'own_mobile_phone',
#        'Salary_wages', 'money_from_trading', 'money_from_providing_services',
#        'casual_labour', 'rental_income', 'money_from_savings', 'pension',
#        'government_grants', 'rely_on_someone', 'no_money', 'other_one',
#        'salary_from_sectors', 'money_from_selling',
#        'money_from_providing_services', 'sent_money_12months_ago',
#        'when_last_sent_money', 'received_money_12months_ago',
#        'when_last_received_money', 'm_m_usage_purchase', 'm_m-bills',
#        'kiswahahili_literate', 'english_literate', 'Latitude', 'Longitude',
#        'mobile_money', 'savings', 'borrowing', 'insurance',
#        'mobile_money_classification'],
#       dtype='object')

# %%
# categories
cat = {
    0 : "No_financial_services",
    1 : "Other_only",
    2 : "Mm_only",
    3 : "Mm_plus"
}
# group and get relevant data
services_age = tan.groupby(["mobile_money_classification", "english_literate"])["ID"].count().reset_index()
font = {
    'weight' : 'normal',
    'size'   : 15
       }
# some settings to make sure client can see text.
plt.rc('font', **font)
plt.figure(figsize=(20,10))
for x in services_age["mobile_money_classification"].unique():
    plt.plot( 'english_literate', 'ID', data=services_age[services_age.english_literate==x],
             marker='', linewidth=3, label="Label for {}".format(cat[x])
            )
plt.title("Relationship between financial services accessed (non-mobile, mobile, both) and english_literate")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-e9ea801ddd71> in <module>
#      17 for x in services_age["mobile_money_classification"].unique():
#      18     plt.plot( 'english_literate', 'ID', data=services_age[services_age.english_literate==x],
# ---> 19              marker='', linewidth=3, label="Label for {}".format(cat[x])
#      20             )
#      21 plt.title("Relationship between financial services accessed (non-mobile, mobile, both) and english_literate")
#
# KeyError: 'mm_least_one_financial_service'

# %%
list = ['gender']
for i in list:
    tan.groupby([i, "english_literate"]).size().unstack().plot(kind='barh', stacked=True, figsize=(15,10), fontsize=20)
    plt.title('{} vs english_literate'.format(i), fontsize=20)
    plt.legend(loc =(1.1, 0.7), fontsize=15)
    plt.show()

# %%
list = ['gender']
for i in list:
    tan.groupby([i, "kiswahahili_literate"]).size().unstack().plot(kind='barh', stacked=True, figsize=(20,15), fontsize=30)
    plt.title('{} vs kiswahahili_literate'.format(i), fontsize=25)
    plt.legend(loc = (1.1, 0.7), fontsize=25)
    plt.ylabel('gender', fontsize=30)
    plt.show()

# %%
from geopy.geocoders import Nominatim
import folium
lat = -6.3728253 ; lon = 34.8924826
Country_map = folium.Map(location=[lat, lon], zoom_start=6)
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_9'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'green',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_5'):
  folium.CircleMarker(
    [lat, long],
    radius = 5,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, lng, label in zip(training[training.mobile_money == 1].Latitude,
              training[training.mobile_money == 1].Longitude,
              str(training.ID)):
  label = folium.Popup(label, parse_html=True)
  folium.CircleMarker(
    [lat, lng],
    radius=5,
    popup=label,
    color='green',
    fill=True,
    fill_color='#3186CC',
    fill_opacity=0.4,
    parse_html=False).add_to(Country_map) 
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_1'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
for lat, long, label in zip(training['Latitude'],training['Longitude'],'Q8_8'):
  folium.CircleMarker(
    [lat, long],
    radius = 10,
    color = 'yellow',
    parse_htmtl=False
  ).add_to(Country_map)
Country_map
